# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If humans someday establish a base or colony, they’d decide any naming for a capital collectively, but under current international law there’s no Moon capital.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 509, 'prompt_tokens': 13, 'total_tokens': 522, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Df3u0UXecQZC7p4gyX7bMubbUIEyI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2184-da38-7d10-856b-4e91b31f7f43-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 509, 'total_tokens': 522, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or sovereign status, so it has no capital. (In fiction, authors sometimes invent capitals like “Lunapolis,” but that's not real.)

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-Df2FeFqwUogZjJfJDosu7wXIdJWKp',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 688,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 640,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 701}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# - Real-world: There is no capital on the Moon. It has no government or inhabitants.
# - Pun/wordplay: The capital letter of the word “Moon” is M.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite - a rocky celestial body with no permanent population or government.
#
# If you're asking about something else, like:
# - A fictional setting (some sci-fi stories do feature lunar cities)
# - A country with "Moon" in its name
# - Something else entirely
#
# Feel free to clarify and I'm happy to help!

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3071, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3070 try:
# -> 3071     response: GenerateContentResponse = self.client.models.generate_content(
#    3072         **request,
#    3073     )
#    3074 except ClientError as e:
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\google\genai\models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
#    6332     model=model, contents=contents, config=parsed_config
#    6333 )
#    6335 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\google\genai\models.py:4767, in Models._generate_content(self, model, contents, config)
#    4765 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4767 response = self._api_client.request(
#    4768     'post', path, request_dict, http_options
#    4769 )
#    4771 if config is not None and getattr(
#    4772     config, 'should_return_http_response', None
#    4773 ):
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1605, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1602 http_request = self._build_request(
#    1603     http_method, path, request_dict, http_options
#    1604 )
# -> 1605 response = self._request(http_request, http_options, stream=False)
#    1606 response_body = (
#    1607     response.response_stream[0] if response.response_stream else ''
#    1608 )
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1396, in BaseApiClient._request(self, http_request, http_options, stream)
#    1395     retry = tenacity.Retrying(**retry_kwargs)
# -> 1396     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1398 return self._retry(self._request_once, http_request, stream)
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File C:\Python314\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File C:\Python314\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1375, in BaseApiClient._request_once(self, http_request, stream)
#    1374   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1375 errors.APIError.raise_for_response(response)
#    1376 return HttpResponse(
#    1377     response.headers, response if stream else [response.text]
#    1378 )
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[8], line 5
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       2
#       3 model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
#       4
# ----> 5 response = model.invoke("What's the capital of the Moon?")
#       6 print(response.content)
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2559, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2556         msg = "Tools are already defined.code_execution tool can't be defined"
#    2557         raise ValueError(msg)
# -> 2559 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3075, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3071     response: GenerateContentResponse = self.client.models.generate_content(
#    3072         **request,
#    3073     )
#    3074 except ClientError as e:
# -> 3075     _handle_client_error(e, request)
#    3077 return _response_to_result(response)
#
# File ~\git\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:166, in _handle_client_error(e, request)
#     164 model_name = request.get("model", "unknown")
#     165 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 166 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-lite' (INVALID_ARGUMENT): 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='7ecdbcd5-2872-4ff7-b1f1-619a281acca6'),
#               AIMessage(content='There is no capital on the Moon. It has no government or permanent population, so no city or capital exists. (In fiction some creators imagine one, but in reality none.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 301, 'prompt_tokens': 13, 'total_tokens': 314, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Df2GdZGLtGhNE3EhIxNKnLAktubtD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2124-fbb8-70e1-a570-c8895d2ab331-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 301, 'total_tokens': 314, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There is no capital on the Moon. It has no government or permanent population, so no city or capital exists. (In fiction some creators imagine one, but in reality none.)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='d52c5b70-b3a7-445a-9995-818683158706'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='70d45fe7-4e6b-4193-948f-4f3daa9c9e2a', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='64c1faa7-58bf-4316-b355-c67a50adfef6'),
#               AIMessage(content='Nice! Since there isn’t a real capital of the Moon, Luna City exists as a fictional setting. Here’s a fleshed-out concept you can use for a story, game, or world-building:\n\n- Quick concept\n  - Luna City is the political and cultural capital of a Lunar Confederation (or Lunar Republic) that governs human settlements on the Moon. It sits in a sheltered crater rim on the near side, with a sprawling network of habitats, research campuses, and a bustling port.\n\n- Location and layout\n  - Location: near the rim of a large crater along Mare Serenitatis on the Moon’s near side, visible in Earth’s sky as a bright, crescent-dotted shoreline.\n  - Layout: a central hub at the crater rim surrounded by concentric rings of domes and tube-links. A vertical spine of high-rise habitats rises from the floor, connected by skybridges and mag-lev transit tubes. The lower crater floor hosts mining facilities, water-ice processing, and logistics docks; the rim hosts government complexes, academies, and cultural districts.\n\n- Government and politics\n  - Government: a federated lunar council where each district elects representatives; an executive council governs day-to-day affairs, with a strong technocratic, science-driven ethos.\n  - Status: Luna City is the political heart and symbolic capital, where treaties, rites, and major policy decisions are announced. The rest of the Moon is more utilitarian—research outposts, mining camps, and agricultural domes.\n  - Tensions: debates over autonomy vs. Earth-directed oversight, resource rights, and the pace of colonization vs. conservation.\n\n- People and culture\n  - Population: tens of thousands to a couple hundred thousand residents, plus transient workers and researchers.\n  - Demographics: Earth-born colonists, scientists, engineers, and a growing community of lunar-born (“selenites”) who’ve never known Earth gravity.\n  - Culture: a blend of Terran traditions filtered through lunar life—longer project cycles, practical humor about gravity, and a pithy, code-like jargon. Two main cultural strands: a formal, research-first etiquette and a street-smart, trade-oriented slang.\n\n- Economy and technology\n  - Economy drivers: helium-3 and water-ice mining, life-support and modular habitat manufacturing, surface construction materials, and space-tourism/history tours.\n  - Tech highlights: solar- and fusion-based microgrids, modular inflatable habitats, autonomous mining drones, AI-assisted governance, and advanced radiation shielding.\n  - Daily life tech: pressurized, gravity-adjusted homes, smart suits integrated with everyday tasks, and transport hubs that shuttle residents quickly between districts.\n\n- Infrastructure and daily life\n  - Transport: a network of mag-lev transit lines, an orbital elevator or lift system to shallow orbits, rover corridors, and skybridges above the rim.\n  - Energy: hybrid solar farms on crater rims plus compact nuclear microreactors; reclaimed water and closed-loop agriculture.\n  - Environment: radiation shielding, regolith shielding for surface modules, artificial day-night cycles for human circadian rhythms, and controlled microclimates inside domes.\n\n- History and timeline (concise)\n  - 2040s–2050s: First permanent bases and rovers establish a foothold on the Moon.\n  - 2060s–2070s: Lunar infrastructure grows; splash of independent research communities forms.\n  - 2090s: Luna City becomes the political and cultural capital of a broader Lunar Confederation.\n  - 2100s: Tensions over autonomy, resource rights, and Earth governance shape political drama and intrigue.\n\n- Visuals and vibe\n  - A gleaming capital ring around a crater rim, with translucent domes, latticework skylights, and a backdrop of endless regolith and Earthlit skies. The skyline blends brutalist efficiency with elegant glass-and-foil entryways. Night scenes glow with soft blue-white lighting from habitat cores and transit hubs.\n\n- Plot hooks and flavo ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# There isn’t a real Luna City today—the Moon has no sovereign capital. If you’re asking for a complete fictional setting you can use in a story, game, or worldbuilding, here’s a rich, self-contained concept you can expand or adapt.
#
# Overview
# - Name and status: Luna City, the capital of the Moon in this setting, a sprawling, high-tech metropolis built to host government, industry, science, and culture in a tightly integrated lunar ecosystem.
# - Tone: Optimistic but grounded; a frontier society that has learned to live with the Moon’s harsh environment while aiming to become a durable, self-sustaining civilization.
#
# Location and geography
# - Location: Rim of a large crater near the lunar south pole (for example, Shackleton Crater’s rim), chosen for access to shadowed regions (for ice) and near-polar sunlight for solar power.
# - terrain: A mix of crater-terrace housing, lava-tube access corridors, and shielded underground sectors. Surface areas are covered with regolith dust, but most activity happens in pressurized domes, tunnels, and sub-surface habitats.
# - climate and day-night cycle: The Moon’s day is ~29.5 Earth days long. Luna City thrives by exploiting periods of extended daylight for solar energy, while ice mining occurs in permanently shadowed zones. Habitats are heavily insulated and shielded from radiation; some zones rotate to create artificial gravity or use continuous life-support-driven gravity.
#
# Government and politics
# - Governance: A constitutional city-state—The Lunar Republic of Luna City (LRLC)—with a bicameral City Assembly and an executive Office of the Chancellor. The government focuses on life support, resource management, research, and infrastructure.
# - Security and order: A civilian-Lunar Guard (a hybrid police-military organization) handles public safety, plus a Space-forces liaison for Earth relations.
# - Earth relations: Earth-based corporations and nations fund or tax Luna City’s operations under the Moon Accords, with a strong emphasis on ISRU (in-situ resource utilization), water rights, and satellite/telecommunication stewardship.
# - Law and culture: Emphasis on scientific merit, industrial transparency, and civil liberties tailored to life in a closed environment. Quarantine, radiation exposure limits, and resource allocation rules are tightly codified.
#
# Society and demographics
# - population: A diverse mix of Earth expatriates, scientists, engineers, miners, medical staff, educators, and artists. The city’s population is designed to scale with its infrastructure, from a few tens of thousands in early days to several hundred thousand as ships and habitats join the network.
# - daily life: People live in pressurized domes and underground neighborhoods connected by maglev tramways and pneumatic transit. Work is often 4–8 hour shifts in three shifts per day, designed for long-term health in low gravity.
# - culture: A synthesis of Earth cultures with a distinct lunar identity: a practical, problem-solving mindset, a strong sense of community, and a growing tradition of “Luna Time”—a shared rhythm that aligns with the Moon’s day-night cycle rather than Earth’s calendar.
# - education and research: A major university complex (The Selene Institute) and multiple specialized research centers focus on lunar science, ISRU, habitat design, radiation physics, and space medicine. Public outreach programs promote science literacy and lunar history.
#
# Economy and infrastructure
# - core industries:
#   - ISRU and mining: extraction of oxygen, metals, and volatiles from lunar regolith and ice in shadowed regions.
#   - energy: solar farms on pole-facing rims with efficient storage systems; possibly small modular nuclear reactors for reliability.
#   - manufacturing and hi-tech: microgravity-friendly fabrication (optics, composites, pharmaceuticals), 3D-printing of habitat components, and lunar-glass production for shielding and optics.
#   - life-support services: water purification, air recycling, and habitat maintenance.
#   - tourism and culture: guided tours of polar lighting, ice-mining sites, orbital views, and lunar arts venues.
# - currency and trade: A regional currency unit (the Sol) used for intercity and Earth-Luna transactions, backed by a mix of resources and services rather than a single commodity.
# - transport and logistics: A network of surface and sub-surface transit:
#   - Surface: maglev tram lines, autonomous rovers, and freight sleds.
#   - Subsurface: tunnel networks to shield from radiation and temperature swings.
#   - Logistics hubs connected to Earth via orbital transfer stations and lunar elevators or tethers.
# - housing and energy: Dome clusters for living with regolith shielding and water-cooled interiors; solar arrays positioned to maximize daylight capture; water ice mined and purified for life support and manufacturing.
#
# Landmarks, districts, and architecture
# - The Helios Dome District: Solar farms and renewable energy management centers, with a striking skyline of transparent and reflective domes that glow at dusk.
# - The Iceworks Quarter: Ice mining facilities and research labs, with cryogenic storage towers and ice-carved public art.
# - The Craterview Market: A bustling hub of commerce, housing museums, cafés, artisan workshops, and performance venues—open-air spaces with panoramic views of the lunar surface.
# - The Subsurface Ring: An interconnected labyrinth of habitat modules and transit tunnels carved into lunar rock, providing radiation shielding and stable temperatures.
# - The Hall of Selene: The seat of government, a monumental complex that blends glass, basalt, and lunar regolith to symbolize transparency and resilience.
# - The Lunar Conservatory: A hub for lunar flora and low-gravity agriculture experiments, with lush terraces and biomes designed to study closed-loop farming.
# - The Observatory Spire: A major research facility with advanced telescopes and instruments for selenology and planetary science.
# - Ice Moon Park: A public space surrounding a shallow crater with sculpted ice formations, luminescent minerals, and light-based art installations.
#
# Technology and science
# - habitation tech: Pressurized habitats with active shielding, air recycling, thermal control, and modular expansion to accommodate growth.
# - life support: Closed-loop systems for air, water, and waste; ISRU facilities supply oxygen and common materials.
# - radiation protection: Dense regolith shielding around habitats, plus active countermeasures in key zones.
# - energy tech: High-efficiency solar arrays, advanced energy storage (thermal and chemical), and backups from compact reactors where needed.
# - transportation tech: Lightweight rovers, maglev lines, personal transit devices, and ladder-free vertical access to many modules.
# - communications: Direct lunar-Earth links with relay satellites, plus local mesh networks for resilience and autonomy.
#
# Culture, arts, and daily life
# - arts and education: The Lunar Arts Guild, drama and music spectacles in domed theaters, and the Selene Institute’s public lectures and science fairs.
# - cuisine: Lunar-root crops grown in controlled environments; Earth-imported staples; creative fusion dishes that leverage microgravity preparation methods and preserved foods from Earth.
# - sports and recreation: Low-gravity sports, zero-G gym spaces, and public observation decks to enjoy the sky and the zodiacal light over the crater rims.
# - religion and philosophy: A secular, science-forward civic culture with ceremonial days tied to lunar phases and harvest cycles rather than terrestrial calendars.
#
# History and timeline (at a glance)
# - Early days: Initial human presence established in small surface outposts and a few pressurized modules.
# - Build-out phase: Emergence of a more permanent, shielded settlement with ISRU facilities and sustainable energy systems.
# - City-state formation: Governance consolidates into the Lunar Republic of Luna City, with infrastructure geared toward long-term independence and Earth-Luna cooperation.
# - Maturity: A diversified economy with robust education, culture, and research sectors; extended trade and terraforming-like projects to optimize living conditions.
#
# Challenges and story hooks (to spark plots)
# - Resource conflicts: Competing claims on water ice reserves in shadowed craters or disputes over ISRU rights with Earth-based mining interests.
# - Infrastructure risk: A solar flare damages a portion of the solar farm, triggering a city-wide emergency and testing the resilience of redundancy systems.
# - Health and safety: Long-term low-gravity health concerns (bone density, muscle atrophy) drive new medical technologies and social policy.
# - Political intrigue: Tensions between Earth-backed factions and autonomous lunar governance, with cyber-espionage or sabotage attempts.
# - Discovery and mystery: An underground lava-tube network reveals ancient lunar geology, or an unexpected resource deposit that could change the city’s future.
# - Environmental tension: Dust-like regolith handling issues or an ice mining operation that destabilizes a local water cycle in a controlled ecosystem.
#
# Character and faction ideas
# - The Chancellor and the Office of the Chancellor: Political leadership focused on public welfare and sustainable growth.
# - The Lunar Guard: Public safety and crisis response; a bridge between civilian life and the broader space governance system.
# - The Selene Institute researchers: Scientists and engineers driving ISRU, medicine, and habitat tech.
# - Icepoint Mining Collective: A company/organization specializing in ice extraction and storage; a powerful economic player.
# - The Moon Conservatory and Arts Guild: Creatives who help humanity connect emotionally with lunar life and who push the boundaries of art in microgravity.
#
# If you want, I can tailor this into a specific vibe:
# - Gritty, cyberpunk-influenced Luna City with corporate power struggles and smuggling networks.
# - Optimistic, frontier-town feel emphasizing science, education, and interplanetary cooperation.
# - Political thriller focusing on governance, diplomacy with Earth, and resource rights.
# - Family-friendly, space-adventure setting with accessible neighborhoods, schools, and community life.
#
# Would you like me to:
# - Create a detailed map with numbered districts and a legend?
# - Write a sample scene (noir, hopeful, or technical) set in Luna City?
# - Produce a character lineup with backstories and relationships?
# - Adapt Luna City to a specific tone, era, or medium (novel, RPG, video game)?
